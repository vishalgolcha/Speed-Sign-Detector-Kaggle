# %%
from sklearn.externals import joblib

# %%
fin = joblib.load('final')

# %%
for i in fin :
    print(i)
# Out:
# (u'Test/06-08 10.29.03.jpg', (270, 590, array([ 0.60485722]), 63, 57))
# (u'Test/03-10 11.21.16.jpg', (20, 20, array([ 0.44413952]), 252, 228))
# (u'Test/02-25 13.32.33.jpg', (460, 620, array([ 0.78118027]), 63, 57))
# (u'Test/04-24 04.19.02.jpg', (90, 170, array([ 0.39288558]), 63, 57))
# (u'Test/03-16 04.32.03.jpg', (0, 170, array([ 0.58351451]), 63, 57))
# (u'Test/03-08 11.43.24.jpg', (160, 390, array([ 0.3997295]), 63, 57))
# (u'Test/03-03 01.06.01.jpg', (60, 360, array([ 0.81204272]), 63, 57))
# (u'Test/08-12 10.02.54.jpg', (80, 360, array([ 0.59809696]), 63, 57))
# (u'Test/02-15 12.12.21.jpg', (50, 200, array([ 0.51116006]), 63, 57))
# (u'Test/03-02 01.14.45.jpg', (10, 30, array([ 0.35519485]), 252, 228))
# (u'Test/06-08 12.54.53.jpg', (90, 30, array([ 0.12627286]), 126, 114))
# (u'Test/08-13 15.51.38.jpg', (290, 0, array([ 0.38890913]), 63, 57))
# (u'Test/03-02 01.20.10.jpg', (160, 330, array([ 0.34607084]), 63, 57))
# ...
